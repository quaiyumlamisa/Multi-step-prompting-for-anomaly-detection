# %%
import pandas as pd
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# %%
df = pd.read_csv("/content/Single_prompt_class.csv")
df.head()

# %%
y_true = df["Label"].astype(int)
y_pred = df["LLM_Lenient_Anomaly"].astype(int)

# %%
acc  = accuracy_score(y_true, y_pred)
prec = precision_score(y_true, y_pred, zero_division=0)
rec  = recall_score(y_true, y_pred, zero_division=0)
f1   = f1_score(y_true, y_pred, zero_division=0)

cm = confusion_matrix(y_true, y_pred)

# %%
print("===== Single Prompt Classification Metrics =====")
print(f"Accuracy : {acc:.4f}")
print(f"Precision: {prec:.4f}")
print(f"Recall   : {rec:.4f}")
print(f"F1 Score : {f1:.4f}")

print("\nConfusion Matrix:")
print(cm)

# %%
df = pd.read_csv("/content/CoT_Anomaly.csv")
df.head()

# %%
y_true = df["Label"].astype(int)
y_pred = df["LLM_CoT_Anomaly"].astype(int)

# %%
acc  = accuracy_score(y_true, y_pred)
prec = precision_score(y_true, y_pred, zero_division=0)
rec  = recall_score(y_true, y_pred, zero_division=0)
f1   = f1_score(y_true, y_pred, zero_division=0)

cm = confusion_matrix(y_true, y_pred)

# %%
print("===== LLM CoT classification =====")
print(f"Accuracy : {acc:.4f}")
print(f"Precision: {prec:.4f}")
print(f"Recall   : {rec:.4f}")
print(f"F1 Score : {f1:.4f}")

print("\nConfusion Matrix:")
print(cm)

# %%
df = pd.read_csv("/content/pipeline_Anomaly.csv")
df.head()
# Out:
#                    BlockId  NumEvents  Label  Pipeline_Prediction  \
# 0  blk_8716244237763720958         13      1                    1
# 1  blk_6291404884140655419         13      1                    1
# 2  blk_8751446418791214913         13      1                    1
# 3  blk_4961970861863065608         13      1                    0
# 4  blk_3888635850409849568         14      1                    1
#
#      Pipeline_Explanation  Pipeline_Confidence
# 0    missing-store-update                 0.78
# 1        late-replication                 0.74
# 2    inconsistent-traffic                 0.69
# 3          normal-pattern                 0.55
# 4  unexpected-termination                 0.82

# %%
y_true = df["Label"].astype(int)
y_pred = df["Pipeline_Prediction"].astype(int)

# %%
acc  = accuracy_score(y_true, y_pred)
prec = precision_score(y_true, y_pred, zero_division=0)
rec  = recall_score(y_true, y_pred, zero_division=0)
f1   = f1_score(y_true, y_pred, zero_division=0)

cm = confusion_matrix(y_true, y_pred)

# %%
print("===== LLM pipeline classification =====")
print(f"Accuracy : {acc:.4f}")
print(f"Precision: {prec:.4f}")
print(f"Recall   : {rec:.4f}")
print(f"F1 Score : {f1:.4f}")

print("\nConfusion Matrix:")
print(cm)
